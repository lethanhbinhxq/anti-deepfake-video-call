# %%
# !nvidia-smi

import os
HOME = os.getcwd()
# Out:
# Sat Apr 13 12:29:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change "/content/gdrive/MyDrive/"  to "/mydrive"
# !ln -s /content/gdrive/MyDrive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
__LINKS__ = {
    'deepfake': 'https://drive.google.com/file/d/19P4eQsa45WJC0ddEl212uqzy3i8jgaWT/view?usp=sharing'
}

# %%
# !mkdir deepfake
# !unzip /content/gdrive/MyDrive/Deepfake/Dataset.zip -d deepfake
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: deepfake/Train/Real/real_685.jpg
#   inflating: deepfake/Train/Real/real_6850.jpg
#   inflating: deepfake/Train/Real/real_68500.jpg
#   inflating: deepfake/Train/Real/real_68501.jpg
#   inflating: deepfake/Train/Real/real_68502.jpg
#   inflating: deepfake/Train/Real/real_68503.jpg
#   inflating: deepfake/Train/Real/real_68504.jpg
#   inflating: deepfake/Train/Real/real_68505.jpg
#   inflating: deepfake/Train/Real/real_68506.jpg
#   inflating: deepfake/Train/Real/real_68507.jpg
#   inflating: deepfake/Train/Real/real_68508.jpg
#   inflating: deepfake/Train/Real/real_68509.jpg
#   inflating: deepfake/Train/Real/real_6851.jpg
#   inflating: deepfake/Train/Real/real_68510.jpg
#   inflating: deepfake/Train/Real/real_68511.jpg
#   inflating: deepfake/Train/Real/real_68512.jpg
#   inflating: deepfake/Train/Real/real_68513.jpg
#   inflating: deepfake/Train/Real/real_68514.jpg
#   inflating: deepfake/Train/Real/real_68515.jpg
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics --quiet

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.4/78.2 GB disk)

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/content/deepfake epochs=10 imgsz=128
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=classify mode=val model=/content/runs/classify/train3/weights/best.pt data=/content/deepfake epochs=10 imgsz=128
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/deepfake/train... found 70500 images in 2 classes ✅
# val: /content/deepfake/val... found 288 images in 2 classes ✅
# test: /content/deepfake/test... found 144 images in 2 classes ✅
# val: Scanning /content/deepfake/val... 288 images, 0 corrupt: 100% 288/288 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                classes   top1_acc   top5_acc: 100% 18/18 [00:01<00:00, 13.91it/s]
#                    all      0.812          1
# Speed: 0.1ms preprocess, 2.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# ...

# %%
# !yolo predict model=/content/runs/classify/train3/weights/best.pt source=/content/testcase/0.jpg
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/testcase/0.jpg: 128x128 Real 1.00, Fake 0.00, 3.4ms
# Speed: 3.8ms preprocess, 3.4ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/classify/train3/weights/best.pt source=/content/testcase/1.jpg
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/testcase/1.jpg: 128x128 Real 1.00, Fake 0.00, 4.9ms
# Speed: 3.9ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict8
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/classify/train3/weights/best.pt source=/content/testcase/2.jpg
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/testcase/2.jpg: 128x128 Real 1.00, Fake 0.00, 4.7ms
# Speed: 4.1ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/classify/train3/weights/best.pt source=/content/testcase/3.jpg
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/testcase/3.jpg: 128x128 Real 1.00, Fake 0.00, 4.7ms
# Speed: 4.1ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/classify/train3/weights/best.pt source=/content/testcase/4.jpg
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/testcase/4.jpg: 128x128 Real 1.00, Fake 0.00, 3.5ms
# Speed: 3.8ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/classify/train3/weights/best.pt source=/content/testcase/fake_44.jpg
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/testcase/fake_44.jpg: 128x128 Fake 0.99, Real 0.01, 4.9ms
# Speed: 3.9ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict12
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
